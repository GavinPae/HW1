# %% [markdown]
# <a href="https://colab.research.google.com/github/GavinPae/HW1/blob/main/Week_3_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_scores.csv')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.shape
# Out:
# (25, 2)

# %%
X=df.drop('Scores',axis=1)
y=df['Scores']

# %%
plt.figure(figsize=(3,3))

plt.scatter(X,y)
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.grid(True)
plt.show()

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=23)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
alpha= model.intercept_
beta=model.coef_
print("alpha","{:.2f}".format(alpha))
print("beta",beta)

print(f"y= {alpha}+{beta}X")
# Out:
# alpha -0.34
# beta [10.28085594]
# y= -0.33798242262133016+[10.28085594]X

# %%
y_pred_train=model.predict(X_train)
y_pred_test=model.predict(X_test)

# %%
plt.figure(figsize=(7,3))

plt.subplot(1,2,1)
plt.scatter(y_train,y_pred_train)
plt.title('training case')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.grid(True)

plt.subplot(1,2,2)
plt.scatter(y_test,y_pred_test)
plt.title('testing case')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.grid(True)

plt.show()

# %%
mse_train=mean_squared_error(y_train,y_pred_train)
mae_train=mean_absolute_error(y_train,y_pred_train)

mse_test=mean_squared_error(y_test,y_pred_test)
mae_test=mean_absolute_error(y_test,y_pred_test)

# %%
performance_df=pd.DataFrame({
    'Metric':['MSE','MAE','MSE','MAE'],
    'DataType':['train','test','train','test'],
    'Value':[mse_train,mae_train,mse_test,mae_test]
})
performance_df.T
# Out:
#                   0         1          2         3
# Metric          MSE       MAE        MSE       MAE
# DataType      train      test      train      test
# Value     26.118428  4.871914  48.168143  6.271379
